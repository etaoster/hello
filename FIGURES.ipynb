# %% [markdown]
# # Comparing bottleneck radius distribution by fenestration
# ![image.png](attachment:image.png)
#
# # Comparing bottleneck radius distribution across subtypes/replicates
# ![image-2.png](attachment:image-2.png)
#
# # Example of fenestration gated by PHE1461 side chain rotations in DII-III hNav1.5
# ![image-3.png](attachment:image-3.png)
#
# # Example of side chain deletions affecting bottleneck radius in hNav1.5
# ![image-5.png](attachment:image-5.png)
# ![image-8.png](attachment:image-8.png)
#
# # Example of side chain deletions affecting bottleneck radius in hNav1.2
# ![image-7.png](attachment:image-7.png)
# ![image-6.png](attachment:image-6.png)
#
# # Free energy landscape of lidocaine exploring the hNav1.5 pore/fenestrations (reconstructed from metadynamics)
# ![image-4.png](attachment:image-4.png)
#
# # Free energy: sliced across fenestration axis DI-II/DIII-IV
# ![image-9.png](attachment:image-9.png)
#
# # Free energy: sliced across fenestration axis DII-III/DI-IV
# ![image-10.png](attachment:image-10.png)
#
# # *RMSD of pore modules for all systems
# ![image-11.png](attachment:image-11.png)
