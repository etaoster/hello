# %% [markdown]
# #### GNUPLOT COMMANDS:
# set key bottom right
#
# p 'negbias_x_6_' u 1:2, 'negbias_x_5_' u 1:2, 'negbias_x_4_' u 1:2, 'negbias_x_3_' u 1:2, 'negbias_x_2_' u 1:2, 'negbias_x_1_' u 1:2
#
# p 'negbias_y_6_' u 1:2, 'negbias_y_5_' u 1:2, 'negbias_y_4_' u 1:2, 'negbias_y_3_' u 1:2, 'negbias_y_2_' u 1:2, 'negbias_y_1_' u 1:2
#
# p 'negbias_z_6_' u 1:2, 'negbias_z_5_' u 1:2, 'negbias_z_4_' u 1:2, 'negbias_z_3_' u 1:2, 'negbias_z_2_' u 1:2, 'negbias_z_1_' u 1:2
#
# # Negbias convergence ~>200ns (x,y,z)
# ![image-3.png](attachment:image-3.png)
# ![image-2.png](attachment:image-2.png)
# ![image.png](attachment:image.png)
