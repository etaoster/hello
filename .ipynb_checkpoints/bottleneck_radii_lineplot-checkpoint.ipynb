# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df1 = pd.read_csv("/Users/Elaine/_COPIED_FILES_/caver_analysis/0-250-400/6J8E_REP1_bottlenecks.csv")
df2 = pd.read_csv("/Users/Elaine/_COPIED_FILES_/caver_analysis/0-250-400/6J8E_REP2_bottlenecks.csv")
df3 = pd.read_csv("/Users/Elaine/_COPIED_FILES_/caver_analysis/0-250-400/6J8E_REP3_bottlenecks.csv")

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Fenestration', 'Snapshot', 'Tunnel cluster', 'Tunnel',
#        'Throughput', 'Cost', 'x', 'y', 'z', 'Bottleneck radius', 'br1', 'br2',
#        'br3', 'br4', 'br5', 'br6', 'br7', 'br8', 'br9', 'br10', 'br11', 'br12',
#        'br13', 'br14', 'br15'],
#       dtype='object')

# %%
df1_12 = df1[df1['Fenestration']=='D1-2']
df1_23 = df1[df1['Fenestration']=='D2-3']
df1_34 = df1[df1['Fenestration']=='D3-4']
df1_14 = df1[df1['Fenestration']=='D1-4']

df2_12 = df2[df2['Fenestration']=='D1-2']
df2_23 = df2[df2['Fenestration']=='D2-3']
df2_34 = df2[df2['Fenestration']=='D3-4']
df2_14 = df2[df2['Fenestration']=='D1-4']

df3_12 = df3[df3['Fenestration']=='D1-2']
df3_23 = df3[df3['Fenestration']=='D2-3']
df3_34 = df3[df3['Fenestration']=='D3-4']
df3_14 = df3[df3['Fenestration']=='D1-4']

# %%
fig, axes = plt.subplots(2, 2, figsize=(20, 12))
fig.suptitle('6J8E (hNav1.2) fenestration bottleneck radii timecourse')
sns.lineplot(x=df1_12['Snapshot'], y=df1_12['Bottleneck radius'], color='blue', ax=axes[0,0], label='REP1')
sns.lineplot(x=df1_23['Snapshot'], y=df1_23['Bottleneck radius'], color='sandybrown', ax=axes[0,1], label='REP1')
sns.lineplot(x=df1_34['Snapshot'], y=df1_34['Bottleneck radius'], color='mediumseagreen', ax=axes[1,0], label='REP1')
sns.lineplot(x=df1_14['Snapshot'], y=df1_14['Bottleneck radius'], color='red', ax=axes[1,1], label='REP1')

sns.lineplot(x=df2_12['Snapshot'], y=df2_12['Bottleneck radius'], color='mediumblue', ax=axes[0,0], label='REP2')
sns.lineplot(x=df2_23['Snapshot'], y=df2_23['Bottleneck radius'], color='orange', ax=axes[0,1], label='REP2')
sns.lineplot(x=df2_34['Snapshot'], y=df2_34['Bottleneck radius'], color='seagreen', ax=axes[1,0], label='REP2')
sns.lineplot(x=df2_14['Snapshot'], y=df2_14['Bottleneck radius'], color='firebrick', ax=axes[1,1], label='REP2')

sns.lineplot(x=df3_12['Snapshot'], y=df3_12['Bottleneck radius'], color='darkblue', ax=axes[0,0], label='REP3')
sns.lineplot(x=df3_23['Snapshot'], y=df3_23['Bottleneck radius'], color='darkorange', ax=axes[0,1], label='REP3')
sns.lineplot(x=df3_34['Snapshot'], y=df3_34['Bottleneck radius'], color='green', ax=axes[1,0], label='REP3')
sns.lineplot(x=df3_14['Snapshot'], y=df3_14['Bottleneck radius'], color='darkred', ax=axes[1,1], label='REP3')
# Out:
# <AxesSubplot:xlabel='Snapshot', ylabel='Bottleneck radius'>
