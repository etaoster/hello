# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df_6j8e_1 = pd.read_csv("/Users/Elaine/_ELAINE_DATA_/caver_concat/0-250-400/6J8E_REP1_bottlenecks.csv", usecols=['Fenestration', 'Snapshot', 'Bottleneck radius'])
df_6j8e_2 = pd.read_csv("/Users/Elaine/_ELAINE_DATA_/caver_concat/0-250-400/6J8E_REP2_bottlenecks.csv", usecols=['Fenestration', 'Snapshot', 'Bottleneck radius'])
df_6j8e_3 = pd.read_csv("/Users/Elaine/_ELAINE_DATA_/caver_concat/0-250-400/6J8E_REP3_bottlenecks.csv", usecols=['Fenestration', 'Snapshot', 'Bottleneck radius'])

# %%
fig, axes = plt.subplots(4, 3, figsize=(20, 25), sharey=True, sharex=True)
fig.suptitle('6J8E (Nav1.2) Fenestration Bottleneck Radii over Simulation Timcourse')

# 0-100ns
sns.histplot(df_6j8e_1[(df_6j8e_1['Fenestration'] == 'D1-2') & (df_6j8e_1['Snapshot'] <= 1000)]['Bottleneck radius'], stat='count', binwidth=0.05, kde='True', ax=axes[0,0], label='D1-2', color='b')
sns.histplot(df_6j8e_1[(df_6j8e_1['Fenestration'] == 'D2-3') & (df_6j8e_1['Snapshot'] <= 1000)]['Bottleneck radius'], stat='count', binwidth=0.05, kde='True', ax=axes[0,0], label='D2-3', color='r')
sns.histplot(df_6j8e_1[(df_6j8e_1['Fenestration'] == 'D3-4') & (df_6j8e_1['Snapshot'] <= 1000)]['Bottleneck radius'], stat='count', binwidth=0.05, kde='True', ax=axes[0,0], label='D3-4', color='c')
sns.histplot(df_6j8e_1[(df_6j8e_1['Fenestration'] == 'D1-4') & (df_6j8e_1['Snapshot'] <= 1000)]['Bottleneck radius'], stat='count', binwidth=0.05, kde='True', ax=axes[0,0], label='D1-4', color='m')
axes[0,0].set_title("Rep 1")

sns.histplot(df_6j8e_2[(df_6j8e_2['Fenestration'] == 'D1-2') & (df_6j8e_2['Snapshot'] <= 1000)]['Bottleneck radius'], stat='count', binwidth=0.05, kde='True', ax=axes[0,1], label='D1-2', color='b')
sns.histplot(df_6j8e_2[(df_6j8e_2['Fenestration'] == 'D2-3') & (df_6j8e_2['Snapshot'] <= 1000)]['Bottleneck radius'], stat='count', binwidth=0.05, kde='True', ax=axes[0,1], label='D2-3', color='r')
sns.histplot(df_6j8e_2[(df_6j8e_2['Fenestration'] == 'D3-4') & (df_6j8e_2['Snapshot'] <= 1000)]['Bottleneck radius'], stat='count', binwidth=0.05, kde='True', ax=axes[0,1], label='D3-4', color='c')
sns.histplot(df_6j8e_2[(df_6j8e_2['Fenestration'] == 'D1-4') & (df_6j8e_2['Snapshot'] <= 1000)]['Bottleneck radius'], stat='count', binwidth=0.05, kde='True', ax=axes[0,1], label='D1-4', color='m')
axes[0,1].set_title("Rep 2")

sns.histplot(df_6j8e_3[(df_6j8e_3['Fenestration'] == 'D1-2') & (df_6j8e_3['Snapshot'] <= 1000)]['Bottleneck radius'], stat='count', binwidth=0.05, kde='True', ax=axes[0,2], label='D1-2', color='b')
sns.histplot(df_6j8e_3[(df_6j8e_3['Fenestration'] == 'D2-3') & (df_6j8e_3['Snapshot'] <= 1000)]['Bottleneck radius'], stat='count', binwidth=0.05, kde='True', ax=axes[0,2], label='D2-3', color='r')
sns.histplot(df_6j8e_3[(df_6j8e_3['Fenestration'] == 'D3-4') & (df_6j8e_3['Snapshot'] <= 1000)]['Bottleneck radius'], stat='count', binwidth=0.05, kde='True', ax=axes[0,2], label='D3-4', color='c')
sns.histplot(df_6j8e_3[(df_6j8e_3['Fenestration'] == 'D1-4') & (df_6j8e_3['Snapshot'] <= 1000)]['Bottleneck radius'], stat='count', binwidth=0.05, kde='True', ax=axes[0,2], label='D1-4', color='m')
axes[0,2].set_title("Rep 3")

# 0-200ns
sns.histplot(df_6j8e_1[(df_6j8e_1['Fenestration'] == 'D1-2') & (df_6j8e_1['Snapshot'] <= 2000)]['Bottleneck radius'], stat='count', binwidth=0.05, kde='True', ax=axes[1,0], label='D1-2', color='b')
sns.histplot(df_6j8e_1[(df_6j8e_1['Fenestration'] == 'D2-3') & (df_6j8e_1['Snapshot'] <= 2000)]['Bottleneck radius'], stat='count', binwidth=0.05, kde='True', ax=axes[1,0], label='D2-3', color='r')
sns.histplot(df_6j8e_1[(df_6j8e_1['Fenestration'] == 'D3-4') & (df_6j8e_1['Snapshot'] <= 2000)]['Bottleneck radius'], stat='count', binwidth=0.05, kde='True', ax=axes[1,0], label='D3-4', color='c')
sns.histplot(df_6j8e_1[(df_6j8e_1['Fenestration'] == 'D1-4') & (df_6j8e_1['Snapshot'] <= 2000)]['Bottleneck radius'], stat='count', binwidth=0.05, kde='True', ax=axes[1,0], label='D1-4', color='m')
axes[1,0].set_title("Rep 1")

sns.histplot(df_6j8e_2[(df_6j8e_2['Fenestration'] == 'D1-2') & (df_6j8e_2['Snapshot'] <= 2000)]['Bottleneck radius'], stat='count', binwidth=0.05, kde='True', ax=axes[1,1], label='D1-2', color='b')
sns.histplot(df_6j8e_2[(df_6j8e_2['Fenestration'] == 'D2-3') & (df_6j8e_2['Snapshot'] <= 2000)]['Bottleneck radius'], stat='count', binwidth=0.05, kde='True', ax=axes[1,1], label='D2-3', color='r')
sns.histplot(df_6j8e_2[(df_6j8e_2['Fenestration'] == 'D3-4') & (df_6j8e_2['Snapshot'] <= 2000)]['Bottleneck radius'], stat='count', binwidth=0.05, kde='True', ax=axes[1,1], label='D3-4', color='c')
sns.histplot(df_6j8e_2[(df_6j8e_2['Fenestration'] == 'D1-4') & (df_6j8e_2['Snapshot'] <= 2000)]['Bottleneck radius'], stat='count', binwidth=0.05, kde='True', ax=axes[1,1], label='D1-4', color='m')
axes[1,1].set_title("Rep 2")

sns.histplot(df_6j8e_3[(df_6j8e_3['Fenestration'] == 'D1-2') & (df_6j8e_3['Snapshot'] <= 2000)]['Bottleneck radius'], stat='count', binwidth=0.05, kde='True', ax=axes[1,2], label='D1-2', color='b')
sns.histplot(df_6j8e_3[(df_6j8e_3['Fenestration'] == 'D2-3') & (df_6j8e_3['Snapshot'] <= 2000)]['Bottleneck radius'], stat='count', binwidth=0.05, kde='True', ax=axes[1,2], label='D2-3', color='r')
sns.histplot(df_6j8e_3[(df_6j8e_3['Fenestration'] == 'D3-4') & (df_6j8e_3['Snapshot'] <= 2000)]['Bottleneck radius'], stat='count', binwidth=0.05, kde='True', ax=axes[1,2], label='D3-4', color='c')
sns.histplot(df_6j8e_3[(df_6j8e_3['Fenestration'] == 'D1-4') & (df_6j8e_3['Snapshot'] <= 2000)]['Bottleneck radius'], stat='count', binwidth=0.05, kde='True', ax=axes[1,2], label='D1-4', color='m')
axes[1,2].set_title("Rep 3")

#0-300ns
sns.histplot(df_6j8e_1[(df_6j8e_1['Fenestration'] == 'D1-2') & (df_6j8e_1['Snapshot'] <= 3000)]['Bottleneck radius'], stat='count', binwidth=0.05, kde='True', ax=axes[2,0], label='D1-2', color='b')
sns.histplot(df_6j8e_1[(df_6j8e_1['Fenestration'] == 'D2-3') & (df_6j8e_1['Snapshot'] <= 3000)]['Bottleneck radius'], stat='count', binwidth=0.05, kde='True', ax=axes[2,0], label='D2-3', color='r')
sns.histplot(df_6j8e_1[(df_6j8e_1['Fenestration'] == 'D3-4') & (df_6j8e_1['Snapshot'] <= 3000)]['Bottleneck radius'], stat='count', binwidth=0.05, kde='True', ax=axes[2,0], label='D3-4', color='c')
sns.histplot(df_6j8e_1[(df_6j8e_1['Fenestration'] == 'D1-4') & (df_6j8e_1['Snapshot'] <= 3000)]['Bottleneck radius'], stat='count', binwidth=0.05, kde='True', ax=axes[2,0], label='D1-4', color='m')
axes[2,0].set_title("Rep 1")

sns.histplot(df_6j8e_2[(df_6j8e_2['Fenestration'] == 'D1-2') & (df_6j8e_2['Snapshot'] <= 3000)]['Bottleneck radius'], stat='count', binwidth=0.05, kde='True', ax=axes[2,1], label='D1-2', color='b')
sns.histplot(df_6j8e_2[(df_6j8e_2['Fenestration'] == 'D2-3') & (df_6j8e_2['Snapshot'] <= 3000)]['Bottleneck radius'], stat='count', binwidth=0.05, kde='True', ax=axes[2,1], label='D2-3', color='r')
sns.histplot(df_6j8e_2[(df_6j8e_2['Fenestration'] == 'D3-4') & (df_6j8e_2['Snapshot'] <= 3000)]['Bottleneck radius'], stat='count', binwidth=0.05, kde='True', ax=axes[2,1], label='D3-4', color='c')
sns.histplot(df_6j8e_2[(df_6j8e_2['Fenestration'] == 'D1-4') & (df_6j8e_2['Snapshot'] <= 3000)]['Bottleneck radius'], stat='count', binwidth=0.05, kde='True', ax=axes[2,1], label='D1-4', color='m')
axes[2,1].set_title("Rep 2")

sns.histplot(df_6j8e_3[(df_6j8e_3['Fenestration'] == 'D1-2') & (df_6j8e_3['Snapshot'] <= 3000)]['Bottleneck radius'], stat='count', binwidth=0.05, kde='True', ax=axes[2,2], label='D1-2', color='b')
sns.histplot(df_6j8e_3[(df_6j8e_3['Fenestration'] == 'D2-3') & (df_6j8e_3['Snapshot'] <= 3000)]['Bottleneck radius'], stat='count', binwidth=0.05, kde='True', ax=axes[2,2], label='D2-3', color='r')
sns.histplot(df_6j8e_3[(df_6j8e_3['Fenestration'] == 'D3-4') & (df_6j8e_3['Snapshot'] <= 3000)]['Bottleneck radius'], stat='count', binwidth=0.05, kde='True', ax=axes[2,2], label='D3-4', color='c')
sns.histplot(df_6j8e_3[(df_6j8e_3['Fenestration'] == 'D1-4') & (df_6j8e_3['Snapshot'] <= 3000)]['Bottleneck radius'], stat='count', binwidth=0.05, kde='True', ax=axes[2,2], label='D1-4', color='m')
axes[2,2].set_title("Rep 3")

#0-400ns
sns.histplot(df_6j8e_1[(df_6j8e_1['Fenestration'] == 'D1-2') & (df_6j8e_1['Snapshot'] <= 4000)]['Bottleneck radius'], stat='count', binwidth=0.05, kde='True', ax=axes[3,0], label='D1-2', color='b')
sns.histplot(df_6j8e_1[(df_6j8e_1['Fenestration'] == 'D2-3') & (df_6j8e_1['Snapshot'] <= 4000)]['Bottleneck radius'], stat='count', binwidth=0.05, kde='True', ax=axes[3,0], label='D2-3', color='r')
sns.histplot(df_6j8e_1[(df_6j8e_1['Fenestration'] == 'D3-4') & (df_6j8e_1['Snapshot'] <= 4000)]['Bottleneck radius'], stat='count', binwidth=0.05, kde='True', ax=axes[3,0], label='D3-4', color='c')
sns.histplot(df_6j8e_1[(df_6j8e_1['Fenestration'] == 'D1-4') & (df_6j8e_1['Snapshot'] <= 4000)]['Bottleneck radius'], stat='count', binwidth=0.05, kde='True', ax=axes[3,0], label='D1-4', color='m')
axes[3,0].set_title("Rep 1")

sns.histplot(df_6j8e_2[(df_6j8e_2['Fenestration'] == 'D1-2') & (df_6j8e_2['Snapshot'] <= 4000)]['Bottleneck radius'], stat='count', binwidth=0.05, kde='True', ax=axes[3,1], label='D1-2', color='b')
sns.histplot(df_6j8e_2[(df_6j8e_2['Fenestration'] == 'D2-3') & (df_6j8e_2['Snapshot'] <= 4000)]['Bottleneck radius'], stat='count', binwidth=0.05, kde='True', ax=axes[3,1], label='D2-3', color='r')
sns.histplot(df_6j8e_2[(df_6j8e_2['Fenestration'] == 'D3-4') & (df_6j8e_2['Snapshot'] <= 4000)]['Bottleneck radius'], stat='count', binwidth=0.05, kde='True', ax=axes[3,1], label='D3-4', color='c')
sns.histplot(df_6j8e_2[(df_6j8e_2['Fenestration'] == 'D1-4') & (df_6j8e_2['Snapshot'] <= 4000)]['Bottleneck radius'], stat='count', binwidth=0.05, kde='True', ax=axes[3,1], label='D1-4', color='m')
axes[3,1].set_title("Rep 2")

sns.histplot(df_6j8e_3[(df_6j8e_3['Fenestration'] == 'D1-2') & (df_6j8e_3['Snapshot'] <= 4000)]['Bottleneck radius'], stat='count', binwidth=0.05, kde='True', ax=axes[3,2], label='D1-2', color='b')
sns.histplot(df_6j8e_3[(df_6j8e_3['Fenestration'] == 'D2-3') & (df_6j8e_3['Snapshot'] <= 4000)]['Bottleneck radius'], stat='count', binwidth=0.05, kde='True', ax=axes[3,2], label='D2-3', color='r')
sns.histplot(df_6j8e_3[(df_6j8e_3['Fenestration'] == 'D3-4') & (df_6j8e_3['Snapshot'] <= 4000)]['Bottleneck radius'], stat='count', binwidth=0.05, kde='True', ax=axes[3,2], label='D3-4', color='c')
sns.histplot(df_6j8e_3[(df_6j8e_3['Fenestration'] == 'D1-4') & (df_6j8e_3['Snapshot'] <= 4000)]['Bottleneck radius'], stat='count', binwidth=0.05, kde='True', ax=axes[3,2], label='D1-4', color='m')
axes[3,2].set_title("Rep 3")

plt.legend()

# %%
fig, axes = plt.subplots(4, 3, figsize=(15, 20), sharex=True, sharey=True)
fig.suptitle('6J8E (Nav1.2) Fenestration Bottleneck Radii : Convergence over simulation timecourse')

# 0-100ns
sns.histplot(df_6j8e_1[(df_6j8e_1['Fenestration'] == 'D1-2') & (df_6j8e_1['Snapshot'] <= 1000)]['Bottleneck radius'], stat='probability', binwidth=0.05, kde='True', ax=axes[0,0], label='D1-2', color='b')
sns.histplot(df_6j8e_1[(df_6j8e_1['Fenestration'] == 'D2-3') & (df_6j8e_1['Snapshot'] <= 1000)]['Bottleneck radius'], stat='probability', binwidth=0.05, kde='True', ax=axes[0,0], label='D2-3', color='r')
sns.histplot(df_6j8e_1[(df_6j8e_1['Fenestration'] == 'D3-4') & (df_6j8e_1['Snapshot'] <= 1000)]['Bottleneck radius'], stat='probability', binwidth=0.05, kde='True', ax=axes[0,0], label='D3-4', color='c')
sns.histplot(df_6j8e_1[(df_6j8e_1['Fenestration'] == 'D1-4') & (df_6j8e_1['Snapshot'] <= 1000)]['Bottleneck radius'], stat='probability', binwidth=0.05, kde='True', ax=axes[0,0], label='D1-4', color='m')
axes[0,0].set_title("0-100ns; Rep 1")

sns.histplot(df_6j8e_2[(df_6j8e_2['Fenestration'] == 'D1-2') & (df_6j8e_2['Snapshot'] <= 1000)]['Bottleneck radius'], stat='probability', binwidth=0.05, kde='True', ax=axes[0,1], label='D1-2', color='b')
sns.histplot(df_6j8e_2[(df_6j8e_2['Fenestration'] == 'D2-3') & (df_6j8e_2['Snapshot'] <= 1000)]['Bottleneck radius'], stat='probability', binwidth=0.05, kde='True', ax=axes[0,1], label='D2-3', color='r')
sns.histplot(df_6j8e_2[(df_6j8e_2['Fenestration'] == 'D3-4') & (df_6j8e_2['Snapshot'] <= 1000)]['Bottleneck radius'], stat='probability', binwidth=0.05, kde='True', ax=axes[0,1], label='D3-4', color='c')
sns.histplot(df_6j8e_2[(df_6j8e_2['Fenestration'] == 'D1-4') & (df_6j8e_2['Snapshot'] <= 1000)]['Bottleneck radius'], stat='probability', binwidth=0.05, kde='True', ax=axes[0,1], label='D1-4', color='m')
axes[0,1].set_title("0-100ns; Rep 2")

sns.histplot(df_6j8e_3[(df_6j8e_3['Fenestration'] == 'D1-2') & (df_6j8e_3['Snapshot'] <= 1000)]['Bottleneck radius'], stat='probability', binwidth=0.05, kde='True', ax=axes[0,2], label='D1-2', color='b')
sns.histplot(df_6j8e_3[(df_6j8e_3['Fenestration'] == 'D2-3') & (df_6j8e_3['Snapshot'] <= 1000)]['Bottleneck radius'], stat='probability', binwidth=0.05, kde='True', ax=axes[0,2], label='D2-3', color='r')
sns.histplot(df_6j8e_3[(df_6j8e_3['Fenestration'] == 'D3-4') & (df_6j8e_3['Snapshot'] <= 1000)]['Bottleneck radius'], stat='probability', binwidth=0.05, kde='True', ax=axes[0,2], label='D3-4', color='c')
sns.histplot(df_6j8e_3[(df_6j8e_3['Fenestration'] == 'D1-4') & (df_6j8e_3['Snapshot'] <= 1000)]['Bottleneck radius'], stat='probability', binwidth=0.05, kde='True', ax=axes[0,2], label='D1-4', color='m')
axes[0,2].set_title("0-100ns; Rep 3")
plt.legend()
# 0-200ns
sns.histplot(df_6j8e_1[(df_6j8e_1['Fenestration'] == 'D1-2') & (df_6j8e_1['Snapshot'] <= 2000)]['Bottleneck radius'], stat='probability', binwidth=0.05, kde='True', ax=axes[1,0], label='D1-2', color='b')
sns.histplot(df_6j8e_1[(df_6j8e_1['Fenestration'] == 'D2-3') & (df_6j8e_1['Snapshot'] <= 2000)]['Bottleneck radius'], stat='probability', binwidth=0.05, kde='True', ax=axes[1,0], label='D2-3', color='r')
sns.histplot(df_6j8e_1[(df_6j8e_1['Fenestration'] == 'D3-4') & (df_6j8e_1['Snapshot'] <= 2000)]['Bottleneck radius'], stat='probability', binwidth=0.05, kde='True', ax=axes[1,0], label='D3-4', color='c')
sns.histplot(df_6j8e_1[(df_6j8e_1['Fenestration'] == 'D1-4') & (df_6j8e_1['Snapshot'] <= 2000)]['Bottleneck radius'], stat='probability', binwidth=0.05, kde='True', ax=axes[1,0], label='D1-4', color='m')
axes[1,0].set_title("0-200ns; Rep 1")

sns.histplot(df_6j8e_2[(df_6j8e_2['Fenestration'] == 'D1-2') & (df_6j8e_2['Snapshot'] <= 2000)]['Bottleneck radius'], stat='probability', binwidth=0.05, kde='True', ax=axes[1,1], label='D1-2', color='b')
sns.histplot(df_6j8e_2[(df_6j8e_2['Fenestration'] == 'D2-3') & (df_6j8e_2['Snapshot'] <= 2000)]['Bottleneck radius'], stat='probability', binwidth=0.05, kde='True', ax=axes[1,1], label='D2-3', color='r')
sns.histplot(df_6j8e_2[(df_6j8e_2['Fenestration'] == 'D3-4') & (df_6j8e_2['Snapshot'] <= 2000)]['Bottleneck radius'], stat='probability', binwidth=0.05, kde='True', ax=axes[1,1], label='D3-4', color='c')
sns.histplot(df_6j8e_2[(df_6j8e_2['Fenestration'] == 'D1-4') & (df_6j8e_2['Snapshot'] <= 2000)]['Bottleneck radius'], stat='probability', binwidth=0.05, kde='True', ax=axes[1,1], label='D1-4', color='m')
axes[1,1].set_title("0-200ns; Rep 2")

sns.histplot(df_6j8e_3[(df_6j8e_3['Fenestration'] == 'D1-2') & (df_6j8e_3['Snapshot'] <= 2000)]['Bottleneck radius'], stat='probability', binwidth=0.05, kde='True', ax=axes[1,2], label='D1-2', color='b')
sns.histplot(df_6j8e_3[(df_6j8e_3['Fenestration'] == 'D2-3') & (df_6j8e_3['Snapshot'] <= 2000)]['Bottleneck radius'], stat='probability', binwidth=0.05, kde='True', ax=axes[1,2], label='D2-3', color='r')
sns.histplot(df_6j8e_3[(df_6j8e_3['Fenestration'] == 'D3-4') & (df_6j8e_3['Snapshot'] <= 2000)]['Bottleneck radius'], stat='probability', binwidth=0.05, kde='True', ax=axes[1,2], label='D3-4', color='c')
sns.histplot(df_6j8e_3[(df_6j8e_3['Fenestration'] == 'D1-4') & (df_6j8e_3['Snapshot'] <= 2000)]['Bottleneck radius'], stat='probability', binwidth=0.05, kde='True', ax=axes[1,2], label='D1-4', color='m')
axes[1,2].set_title("0-200ns; Rep 3")

#0-300ns
sns.histplot(df_6j8e_1[(df_6j8e_1['Fenestration'] == 'D1-2') & (df_6j8e_1['Snapshot'] <= 3000)]['Bottleneck radius'], stat='probability', binwidth=0.05, kde='True', ax=axes[2,0], label='D1-2', color='b')
sns.histplot(df_6j8e_1[(df_6j8e_1['Fenestration'] == 'D2-3') & (df_6j8e_1['Snapshot'] <= 3000)]['Bottleneck radius'], stat='probability', binwidth=0.05, kde='True', ax=axes[2,0], label='D2-3', color='r')
sns.histplot(df_6j8e_1[(df_6j8e_1['Fenestration'] == 'D3-4') & (df_6j8e_1['Snapshot'] <= 3000)]['Bottleneck radius'], stat='probability', binwidth=0.05, kde='True', ax=axes[2,0], label='D3-4', color='c')
sns.histplot(df_6j8e_1[(df_6j8e_1['Fenestration'] == 'D1-4') & (df_6j8e_1['Snapshot'] <= 3000)]['Bottleneck radius'], stat='probability', binwidth=0.05, kde='True', ax=axes[2,0], label='D1-4', color='m')
axes[2,0].set_title("0-300ns; Rep 1")

sns.histplot(df_6j8e_2[(df_6j8e_2['Fenestration'] == 'D1-2') & (df_6j8e_2['Snapshot'] <= 3000)]['Bottleneck radius'], stat='probability', binwidth=0.05, kde='True', ax=axes[2,1], label='D1-2', color='b')
sns.histplot(df_6j8e_2[(df_6j8e_2['Fenestration'] == 'D2-3') & (df_6j8e_2['Snapshot'] <= 3000)]['Bottleneck radius'], stat='probability', binwidth=0.05, kde='True', ax=axes[2,1], label='D2-3', color='r')
sns.histplot(df_6j8e_2[(df_6j8e_2['Fenestration'] == 'D3-4') & (df_6j8e_2['Snapshot'] <= 3000)]['Bottleneck radius'], stat='probability', binwidth=0.05, kde='True', ax=axes[2,1], label='D3-4', color='c')
sns.histplot(df_6j8e_2[(df_6j8e_2['Fenestration'] == 'D1-4') & (df_6j8e_2['Snapshot'] <= 3000)]['Bottleneck radius'], stat='probability', binwidth=0.05, kde='True', ax=axes[2,1], label='D1-4', color='m')
axes[2,1].set_title("0-300ns; Rep 2")

sns.histplot(df_6j8e_3[(df_6j8e_3['Fenestration'] == 'D1-2') & (df_6j8e_3['Snapshot'] <= 3000)]['Bottleneck radius'], stat='probability', binwidth=0.05, kde='True', ax=axes[2,2], label='D1-2', color='b')
sns.histplot(df_6j8e_3[(df_6j8e_3['Fenestration'] == 'D2-3') & (df_6j8e_3['Snapshot'] <= 3000)]['Bottleneck radius'], stat='probability', binwidth=0.05, kde='True', ax=axes[2,2], label='D2-3', color='r')
sns.histplot(df_6j8e_3[(df_6j8e_3['Fenestration'] == 'D3-4') & (df_6j8e_3['Snapshot'] <= 3000)]['Bottleneck radius'], stat='probability', binwidth=0.05, kde='True', ax=axes[2,2], label='D3-4', color='c')
sns.histplot(df_6j8e_3[(df_6j8e_3['Fenestration'] == 'D1-4') & (df_6j8e_3['Snapshot'] <= 3000)]['Bottleneck radius'], stat='probability', binwidth=0.05, kde='True', ax=axes[2,2], label='D1-4', color='m')
axes[2,2].set_title("0-300ns; Rep 3")

#0-400ns
sns.histplot(df_6j8e_1[(df_6j8e_1['Fenestration'] == 'D1-2') & (df_6j8e_1['Snapshot'] <= 4000)]['Bottleneck radius'], stat='probability', binwidth=0.05, kde='True', ax=axes[3,0], label='D1-2', color='b')
sns.histplot(df_6j8e_1[(df_6j8e_1['Fenestration'] == 'D2-3') & (df_6j8e_1['Snapshot'] <= 4000)]['Bottleneck radius'], stat='probability', binwidth=0.05, kde='True', ax=axes[3,0], label='D2-3', color='r')
sns.histplot(df_6j8e_1[(df_6j8e_1['Fenestration'] == 'D3-4') & (df_6j8e_1['Snapshot'] <= 4000)]['Bottleneck radius'], stat='probability', binwidth=0.05, kde='True', ax=axes[3,0], label='D3-4', color='c')
sns.histplot(df_6j8e_1[(df_6j8e_1['Fenestration'] == 'D1-4') & (df_6j8e_1['Snapshot'] <= 4000)]['Bottleneck radius'], stat='probability', binwidth=0.05, kde='True', ax=axes[3,0], label='D1-4', color='m')
axes[3,0].set_title("0-400ns; Rep 1")

sns.histplot(df_6j8e_2[(df_6j8e_2['Fenestration'] == 'D1-2') & (df_6j8e_2['Snapshot'] <= 4000)]['Bottleneck radius'], stat='probability', binwidth=0.05, kde='True', ax=axes[3,1], label='D1-2', color='b')
sns.histplot(df_6j8e_2[(df_6j8e_2['Fenestration'] == 'D2-3') & (df_6j8e_2['Snapshot'] <= 4000)]['Bottleneck radius'], stat='probability', binwidth=0.05, kde='True', ax=axes[3,1], label='D2-3', color='r')
sns.histplot(df_6j8e_2[(df_6j8e_2['Fenestration'] == 'D3-4') & (df_6j8e_2['Snapshot'] <= 4000)]['Bottleneck radius'], stat='probability', binwidth=0.05, kde='True', ax=axes[3,1], label='D3-4', color='c')
sns.histplot(df_6j8e_2[(df_6j8e_2['Fenestration'] == 'D1-4') & (df_6j8e_2['Snapshot'] <= 4000)]['Bottleneck radius'], stat='probability', binwidth=0.05, kde='True', ax=axes[3,1], label='D1-4', color='m')
axes[3,1].set_title("0-400ns; Rep 2")

sns.histplot(df_6j8e_3[(df_6j8e_3['Fenestration'] == 'D1-2') & (df_6j8e_3['Snapshot'] <= 4000)]['Bottleneck radius'], stat='probability', binwidth=0.05, kde='True', ax=axes[3,2], label='D1-2', color='b')
sns.histplot(df_6j8e_3[(df_6j8e_3['Fenestration'] == 'D2-3') & (df_6j8e_3['Snapshot'] <= 4000)]['Bottleneck radius'], stat='probability', binwidth=0.05, kde='True', ax=axes[3,2], label='D2-3', color='r')
sns.histplot(df_6j8e_3[(df_6j8e_3['Fenestration'] == 'D3-4') & (df_6j8e_3['Snapshot'] <= 4000)]['Bottleneck radius'], stat='probability', binwidth=0.05, kde='True', ax=axes[3,2], label='D3-4', color='c')
sns.histplot(df_6j8e_3[(df_6j8e_3['Fenestration'] == 'D1-4') & (df_6j8e_3['Snapshot'] <= 4000)]['Bottleneck radius'], stat='probability', binwidth=0.05, kde='True', ax=axes[3,2], label='D1-4', color='m')
axes[3,2].set_title("0-400ns; Rep 3")
# Out:
# No handles with labels found to put in legend.
# Text(0.5, 1.0, '0-400ns; Rep 3')
