# %%
import mdtraj as md 
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
nc_filepath1 = '/home/elaine/elaine_data/EQ_PROD_0-500/6J8E_WTR/6J8E_rep1_prod_0-500_s6only.nc'
nc_filepath2 = '/home/elaine/elaine_data/EQ_PROD_0-500/6J8E_WTR/6J8E_rep2_prod_0-500_s6only.nc'
prm_filepath = '/home/elaine/elaine_data/EQ_PROD_0-500/6J8E_WTR/s6.6J8E_WTR_system.prmtop'

# %%
rep1 = md.load(nc_filepath1, top=prm_filepath)
rep2 = md.load(nc_filepath2, top=prm_filepath)

# %%
chi_r1 = md.compute_chi1(rep1)

# %%
sns.lineplot(np.arange(1,5001), chi_r1[1][:,14]) 
plt.ylim(-3, 0)
# Out:
# /home/elaine/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# (-3.0, 0.0)

# %%
chi_r2 = md.compute_chi1(rep2)
plt.ylim(-3, 0)
sns.lineplot(np.arange(1,5001), chi_r2[1][:,14])
# Out:
# /home/elaine/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>
